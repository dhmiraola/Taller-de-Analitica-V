# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Ruta principal donde están las subcarpetas de las clases
dataset = r"C:\Users\Usuario\Taller de analitica vespertino\2025\pokemones\pokemones"

# %%
import os

# Listar las carpetas de las clases
classes = os.listdir(dataset)
print(f"Clases detectadas: {classes}")
# Out:
# Clases detectadas: ['charmander', 'squirtle']

# %%
# Contar la cantidad de imágenes en cada clase
for class_name in classes:
    class_path = os.path.join(dataset, class_name)
    if os.path.isdir(class_path):
        print(f"{class_name}: {len(os.listdir(class_path))} imágenes")
# Out:
# charmander: 20 imágenes
# squirtle: 20 imágenes

# %%
# Visualizamos una imagen por cada carpeta
from PIL import Image
import matplotlib.pyplot as plt

# Mostrar una imagen de cada clase
plt.figure(figsize=(10, 5))
for i, class_name in enumerate(classes):
    class_path = os.path.join(dataset, class_name)
    first_image_path = os.path.join(class_path, os.listdir(class_path)[0])
    img = Image.open(first_image_path)

    plt.subplot(1, len(classes), i + 1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis('off')
plt.show()

# %%
# Visualizamos las dimensiones, los canales, los bits y el formato de cada imagen 

from PIL import Image, UnidentifiedImageError
import os

# Extensiones soportadas, agrega si tienes otro formato distinto
valid_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".tiff", 'tif'}

# Inspeccionar cada imagen y extraer sus características
for class_name in os.listdir(dataset):
    class_path = os.path.join(dataset, class_name)
    if os.path.isdir(class_path):
        print(f"\nClase: {class_name}")
        images = os.listdir(class_path)

        for img_name in images:
            img_path = os.path.join(class_path, img_name)

            # Verificar extensión del archivo
            if not os.path.splitext(img_path)[1].lower() in valid_extensions:
                print(f"Archivo no soportado (omitido): {img_name}")
                continue

            try:
                # Abrir y analizar la imagen
                with Image.open(img_path) as img:
                    dimensions = img.size  # (ancho, alto)
                    mode = img.mode  # Modo de color (e.g., RGB, L, etc.)
                    bits = img.bits if hasattr(img, 'bits') else 'Desconocido'  # Bits por canal
                    fmt = img.format  # Formato de la imagen
                    print(f"Imagen: {img_name} - Dimensiones: {dimensions}, Canales: {mode}, Bits: {bits}, Formato: {fmt}")
            except UnidentifiedImageError:
                print(f"Error: No se pudo identificar la imagen: {img_name}")
# Out:
# Clase: charmander
# Imagen: char001.png - Dimensiones: (475, 475), Canales: RGBA, Bits: Desconocido, Formato: PNG
# Imagen: char002.jpg - Dimensiones: (600, 900), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char003.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char004.png - Dimensiones: (256, 256), Canales: RGBA, Bits: Desconocido, Formato: PNG
# Imagen: char005.jpeg - Dimensiones: (224, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char006.jpeg - Dimensiones: (275, 183), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char007.jpg - Dimensiones: (540, 540), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char008.jpg - Dimensiones: (236, 289), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char009.jpeg - Dimensiones: (220, 229), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char010.jpeg - Dimensiones: (255, 198), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char011.png - Dimensiones: (215, 235), Canales: P, Bits: Desconocido, Formato: PNG
# Imagen: char012.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char013.jpeg - Dimensiones: (244, 206), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char014.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char015.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char016.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char017.jpeg - Dimensiones: (198, 254), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char018.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char019.jpg - Dimensiones: (236, 288), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: char020.png - Dimensiones: (673, 585), Canales: RGBA, Bits: Desconocido, Formato: PNG
#
# Clase: squirtle
# Imagen: sqr001.png - Dimensiones: (475, 475), Canales: RGBA, Bits: Desconocido, Formato: PNG
# Imagen: sqr002.jpeg - Dimensiones: (211, 238), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr003.jpeg - Dimensiones: (300, 168), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr004.jpg - Dimensiones: (1280, 720), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr005.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr006.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr007.jpeg - Dimensiones: (261, 193), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr008.jpeg - Dimensiones: (231, 218), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr009.jpg - Dimensiones: (1800, 1800), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr010.jpg - Dimensiones: (720, 720), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr011.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr012.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr013.png - Dimensiones: (800, 800), Canales: P, Bits: Desconocido, Formato: PNG
# Imagen: sqr014.jpg - Dimensiones: (736, 1117), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr015.jpg - Dimensiones: (600, 706), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr016.jpg - Dimensiones: (460, 460), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr017.jpg - Dimensiones: (900, 900), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr018.png - Dimensiones: (221, 228), Canales: P, Bits: Desconocido, Formato: PNG
# Imagen: sqr019.jpeg - Dimensiones: (225, 225), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: sqr020.png - Dimensiones: (540, 492), Canales: RGBA, Bits: Desconocido, Formato: PNG

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from PIL import Image
from tensorflow.keras.optimizers.legacy import RMSprop

# Estandarización de imágenes
img_height, img_width = 128, 128  # Ajustar el tamaño de las imágenes
num_classes = 2  # Número de clases (ajustar según tu caso)

# Cargar las imágenes
x_data = []
labels = []  # Lista para almacenar las etiquetas verdaderas

for class_name in os.listdir(dataset):
    class_path = os.path.join(dataset, class_name)
    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            try:
                # Verificar que sea un archivo de imagen
                if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff', 'tif')):
                    img = Image.open(img_path).convert("RGB")
                    img = img.resize((img_width, img_height))
                    x_data.append(np.array(img))
                    labels.append(class_name)  # Guardar la etiqueta verdadera
            except Exception as e:
                print(f"Error al procesar la imagen {img_name}: {e}")

# Convertir las listas a arrays NumPy
x_data = np.array(x_data, dtype="float32") / 255.0  # Normalizar
labels = np.array(labels)

# Convertir etiquetas a formato one-hot encoding
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_data = label_encoder.fit_transform(labels)  # Convertir etiquetas a índices numéricos
y_data = to_categorical(y_data, num_classes=num_classes)  # One-hot encoding

# Dividir los datos en entrenamiento y validación
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# Crear el modelo
model = Sequential()
model.add(Conv2D(32, 3, padding='same', input_shape=(img_height, img_width, 3), activation='relu'))
model.add(Conv2D(32, 3, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(Conv2D(64, 3, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='sigmoid'))

# Compilar el modelo
model.compile(optimizer=RMSprop(learning_rate=0.001, decay=1e-6),
              loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
batch_size = 8
epochs = 50

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test))

# Evaluar el modelo
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Loss en test: {test_loss}, Accuracy en test: {test_accuracy}")
# Out:
# Epoch 1/50
# 4/4 [==============================] - 5s 980ms/step - loss: 4.5945 - accuracy: 0.5625 - val_loss: 0.6828 - val_accuracy: 1.0000
# Epoch 2/50
# 4/4 [==============================] - 4s 899ms/step - loss: 0.7075 - accuracy: 0.6562 - val_loss: 0.6043 - val_accuracy: 0.5000
# Epoch 3/50
# 4/4 [==============================] - 4s 946ms/step - loss: 1.4557 - accuracy: 0.3750 - val_loss: 0.6910 - val_accuracy: 0.6250
# Epoch 4/50
# 4/4 [==============================] - 4s 963ms/step - loss: 0.7128 - accuracy: 0.6875 - val_loss: 0.6903 - val_accuracy: 0.6250
# Epoch 5/50
# 4/4 [==============================] - 4s 922ms/step - loss: 0.6464 - accuracy: 0.7188 - val_loss: 0.6646 - val_accuracy: 0.3750
# Epoch 6/50
- accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0042 - accuracy: 1.0000
# Loss en test: 0.004182287026196718, Accuracy en test: 1.0

# %%
import matplotlib.pyplot as plt

# Crear figura
fig = plt.figure(figsize=(10, 8))

# Gráfico de la función de pérdida
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(history.history['loss'], label='Pérdida de entrenamiento')
ax1.plot(history.history['val_loss'], label='Pérdida de Prueba', linestyle='--')
ax1.set_title('Función de pérdida')
ax1.set_ylabel('Pérdida')
ax1.legend(loc='upper right')

# Gráfico de precisión
ax2 = fig.add_subplot(2, 1, 2, sharex=ax1)
ax2.plot(history.history['accuracy'], label='Precisión de entrenamiento')
ax2.plot(history.history['val_accuracy'], label='Precisión de Prueba', linestyle='--')
ax2.set_title('Precisión')
ax2.set_ylabel('Precisión')
ax2.set_xlabel('Épocas')
ax2.legend(loc='lower right')

# Ocultar etiquetas de los ejes x del primer gráfico
plt.setp(ax1.get_xticklabels(), visible=False)

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predicciones del modelo
y_pred = np.argmax(model.predict(x_test), axis=1)
y_true = np.argmax(y_test, axis=1)

# Matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred)

# Visualización de la matriz de confusión
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Métricas
print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))
# Out:
# 1/1 [==============================] - 0s 351ms/step
#               precision    recall  f1-score   support
#
#   charmander       1.00      1.00      1.00         5
#     squirtle       1.00      1.00      1.00         3
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %%
# Guardar el modelo en la ruta especificada
save_path = r"C:\Usuarios\Diego\pokemones.h5"
model.save(save_path)
print(f"Modelo guardado en: {save_path}")
# Out:
# C:\Users\Usuario\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Modelo guardado en: C:\Usuarios\Diego\pokemones.h5

# %%
from tensorflow.keras.models import load_model

# Ruta del modelo guardado
load_path =  r"C:\Usuarios\Diego\pokemones.h5"
# Cargar el modelo
loaded_model = load_model(load_path)
print(f"Modelo cargado desde: {load_path}")
# Out:
# Modelo cargado desde: C:\Usuarios\Diego\pokemones.h5

# %%
import os
import numpy as np
from PIL import Image

# Ruta del dataset "train"
train_dataset_path = r"C:\Users\Usuario\Taller de analitica vespertino\2025\pokemones\test"

# Dimensiones de las imágenes (deben coincidir con el modelo)
img_height, img_width = 128, 128

# Procesar las imágenes dentro de subcarpetas
x_train_data = []
image_names = []
labels = []  # Opcional: guardar el nombre de la clase para referencia

for class_name in os.listdir(train_dataset_path):
    class_path = os.path.join(train_dataset_path, class_name)
    if os.path.isdir(class_path):  # Solo procesar directorios
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            try:
                # Verificar que sea un archivo de imagen
                if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                    img = Image.open(img_path).convert("RGB")
                    img = img.resize((img_width, img_height))
                    x_train_data.append(np.array(img))
                    image_names.append(img_name)
                    labels.append(class_name)  # Opcional: asociar con la clase
            except Exception as e:
                print(f"Error al procesar la imagen {img_name}: {e}")

# Convertir a NumPy array y normalizar
x_train_data = np.array(x_train_data, dtype="float32") / 255.0

# %%
# Cargar el modelo guardado
model_path = r"C:\Usuarios\Diego\pokemones.h5"
model = load_model(model_path)

# Realizar predicciones
predictions = model.predict(x_train_data)

# Convertir predicciones a etiquetas
predicted_labels = np.argmax(predictions, axis=1)

# Crear un grid para visualizar las imágenes con predicciones
num_images = len(x_train_data)
num_cols = 3
num_rows = (num_images + num_cols - 1) // num_cols  # Calcular filas necesarias

plt.figure(figsize=(15, 5 * num_rows))

for i, (img, label) in enumerate(zip(x_train_data, predicted_labels)):
    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(img)
    plt.title(f"Clase predicha: {label_encoder.inverse_transform([label])[0]}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 193ms/step
