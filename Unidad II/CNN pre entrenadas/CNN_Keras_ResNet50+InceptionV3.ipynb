# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Montar Google Drive para acceder a los datos
# from google.colab import drive
# drive.mount('/content/drive')

# Ruta del dataset en Google Drive
# dataset = '//content/drive/MyDrive/Colab Notebooks/M15S19/imagenes'

# %%
# Ruta principal donde están las subcarpetas de las clases
dataset = r"C:\Users\Diego\Tarea UDD\Clase 3\imagenes"

# %% [markdown]
# ## Analisis Exploratorio del dataset

# %%
import os

# Listar las carpetas de las clases
classes = os.listdir(dataset)
print(f"Clases detectadas: {classes}")
# Out:
# Clases detectadas: ['autos', 'aviones', 'camiones']

# %%
# Contar la cantidad de imágenes en cada clase
for class_name in classes:
    class_path = os.path.join(dataset, class_name)
    if os.path.isdir(class_path):
        print(f"{class_name}: {len(os.listdir(class_path))} imágenes")
# Out:
# autos: 20 imágenes
# aviones: 20 imágenes
# camiones: 20 imágenes

# %%
# Visualizamos una imagen por cada carpeta
from PIL import Image
import matplotlib.pyplot as plt

# Mostrar una imagen de cada clase
plt.figure(figsize=(10, 5))
for i, class_name in enumerate(classes):
    class_path = os.path.join(dataset, class_name)
    first_image_path = os.path.join(class_path, os.listdir(class_path)[0])
    img = Image.open(first_image_path)

    plt.subplot(1, len(classes), i + 1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis('off')
plt.show()

# %%
# Visualizamos las dimensiones, los canales, los bits y el formato de cada imagen 

from PIL import Image, UnidentifiedImageError
import os

# Extensiones soportadas, agrega si tienes otro formato distinto
valid_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".tiff"}

# Inspeccionar cada imagen y extraer sus características
for class_name in os.listdir(dataset):
    class_path = os.path.join(dataset, class_name)
    if os.path.isdir(class_path):
        print(f"\nClase: {class_name}")
        images = os.listdir(class_path)

        for img_name in images:
            img_path = os.path.join(class_path, img_name)

            # Verificar extensión del archivo
            if not os.path.splitext(img_path)[1].lower() in valid_extensions:
                print(f"Archivo no soportado (omitido): {img_name}")
                continue

            try:
                # Abrir y analizar la imagen
                with Image.open(img_path) as img:
                    dimensions = img.size  # (ancho, alto)
                    mode = img.mode  # Modo de color (e.g., RGB, L, etc.)
                    bits = img.bits if hasattr(img, 'bits') else 'Desconocido'  # Bits por canal
                    fmt = img.format  # Formato de la imagen
                    print(f"Imagen: {img_name} - Dimensiones: {dimensions}, Canales: {mode}, Bits: {bits}, Formato: {fmt}")
            except UnidentifiedImageError:
                print(f"Error: No se pudo identificar la imagen: {img_name}")
# Out:
# Clase: autos
# Imagen: auto001.jpg - Dimensiones: (826, 826), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto002.jpg - Dimensiones: (1380, 789), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto003.jpg - Dimensiones: (1060, 795), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto004.jpg - Dimensiones: (1800, 900), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto005.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto006.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto007.jpg - Dimensiones: (996, 796), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto008.jpg - Dimensiones: (1380, 776), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto009.jpg - Dimensiones: (1380, 776), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto010.jpg - Dimensiones: (1380, 776), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto011.jpg - Dimensiones: (1380, 776), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto012.jpg - Dimensiones: (1380, 776), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto013.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto014.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto015.jpg - Dimensiones: (1060, 795), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto016.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto017.jpg - Dimensiones: (1060, 795), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto018.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto019.jpg - Dimensiones: (1380, 765), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: auto020.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
#
# Clase: aviones
# Imagen: avion001.jpg - Dimensiones: (1500, 901), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion002.jpg - Dimensiones: (1380, 773), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion003.jpg - Dimensiones: (740, 1110), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion004.jpg - Dimensiones: (1800, 896), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion005.jpg - Dimensiones: (1060, 771), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion006.jpg - Dimensiones: (1380, 642), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion007.jpg - Dimensiones: (1380, 965), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion008.jpg - Dimensiones: (626, 626), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion009.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion010.jpg - Dimensiones: (740, 926), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion011.jpg - Dimensiones: (1380, 937), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion012.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion013.jpg - Dimensiones: (1380, 945), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion014.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion015.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion016.jpg - Dimensiones: (826, 826), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion017.jpg - Dimensiones: (1380, 399), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion018.jpg - Dimensiones: (900, 769), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion019.jpg - Dimensiones: (1380, 979), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: avion020.jpg - Dimensiones: (826, 826), Canales: RGB, Bits: 8, Formato: JPEG
#
# Clase: camiones
# Imagen: camion001.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion002.jpg - Dimensiones: (900, 600), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion003.jpg - Dimensiones: (1110, 577), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion004.jpg - Dimensiones: (1380, 773), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion005.jpg - Dimensiones: (1500, 1215), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion006.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion007.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion008.jpg - Dimensiones: (826, 826), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion009.jpg - Dimensiones: (1380, 776), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion010.jpg - Dimensiones: (1800, 900), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion011.jpg - Dimensiones: (996, 797), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion012.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion013.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion014.jpg - Dimensiones: (1380, 789), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion015.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion016.jpg - Dimensiones: (1380, 459), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion017.jpg - Dimensiones: (1380, 776), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion018.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion019.jpg - Dimensiones: (826, 826), Canales: RGB, Bits: 8, Formato: JPEG
# Imagen: camion020.jpg - Dimensiones: (1380, 920), Canales: RGB, Bits: 8, Formato: JPEG

# %% [markdown]
# ## Creamos el modelo de red neuronal convolucional

# %%
import os
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50, InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, concatenate, Input
from sklearn.model_selection import train_test_split
from PIL import Image
from tensorflow.keras.optimizers.legacy import RMSprop
from sklearn.preprocessing import LabelEncoder

# Parámetros
img_height, img_width = 128, 128  # Ajustar tamaño de las imágenes
num_classes = 3  # Número de clases (ajustar según tu caso)
batch_size = 8
epochs = 50

# Cargar las imágenes
x_data = []
labels = []

for class_name in os.listdir(dataset):
    class_path = os.path.join(dataset, class_name)
    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            try:
                if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                    img = Image.open(img_path).convert("RGB")
                    img = img.resize((img_width, img_height))
                    x_data.append(np.array(img))
                    labels.append(class_name)
            except Exception as e:
                print(f"Error al procesar la imagen {img_name}: {e}")

# Convertir las listas a arrays NumPy
x_data = np.array(x_data, dtype="float32") / 255.0  # Normalizar
labels = np.array(labels)

# Convertir etiquetas a formato one-hot encoding
label_encoder = LabelEncoder()
y_data = label_encoder.fit_transform(labels)
y_data = to_categorical(y_data, num_classes=num_classes)

# Dividir los datos en entrenamiento y validación
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# Crear la entrada del modelo
input_tensor = Input(shape=(img_height, img_width, 3))

# Modelo base ResNet50
resnet_base = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
resnet_output = GlobalAveragePooling2D()(resnet_base.output)

# Modelo base InceptionV3
inception_base = InceptionV3(weights='imagenet', include_top=False, input_tensor=input_tensor)
inception_output = GlobalAveragePooling2D()(inception_base.output)

# Fusionar las salidas de ResNet50 e InceptionV3
merged = concatenate([resnet_output, inception_output])

# Agregar capas densas
x = Dense(512, activation='relu')(merged)
x = Dropout(0.5)(x)
output_tensor = Dense(num_classes, activation='softmax')(x)

# Crear el modelo final
model = Model(inputs=input_tensor, outputs=output_tensor)

# Congelar las capas de los modelos base
for layer in resnet_base.layers:
    layer.trainable = False
for layer in inception_base.layers:
    layer.trainable = False

# Compilar el modelo
model.compile(optimizer=RMSprop(learning_rate=0.001, decay=1e-6),
              loss='categorical_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test))

# Evaluar el modelo
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Loss en test: {test_loss}, Accuracy en test: {test_accuracy}")
# Out:
# WARNING:tensorflow:From C:\Users\Diego\anaconda3\envs\gpu\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Diego\anaconda3\envs\gpu\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Diego\anaconda3\envs\gpu\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Diego\anaconda3\envs\gpu\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Diego\anaconda3\envs\gpu\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6/6 [==============================] - 7s 487ms/step - loss: 9.8798 - accuracy: 0.4583 - val_loss: 9.1789e-06 - val_accuracy: 1.0000
# Epoch 2/50
# 6/6 [==============================] - 1s 173ms/step - loss: 0.0408 - accuracy: 0.9792 - val_loss: 0.1350 - val_accuracy: 0.9167
# Epoch 3/50
# 6/6 [==============================] - 1s 182ms/step - loss: 0.0492 - accuracy: 0.9792 - val_loss: 0.1432 - val_accuracy: 0.9167
# Epoch 4/50
# 6/6 [==============================] - 1s 179ms/step - loss: 0.8611 - accuracy: 0.8750 - val_loss: 7.8037e-05 - val_accuracy: 1.0000
# Epoch 5/50
# 6/6 [==============================] - 1s 181ms/step - loss: 0.0493 - accuracy: 0.9792 - val_loss: 0.3288 - val_accuracy: 0.9167
# Epoch 6/50
# 6/6 [==============================] - 1s 183ms/step - loss: 0.2182 - accuracy: 0.9583 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 7/50
# 6/6 [==============================] - 1s 172ms/step - loss: 0.0654 - accuracy: 0.9792 - val_loss: 0.0585 - val_accuracy: 1.0000
# Epoch 8/50
# 6/6 [==============================] - 1s 171ms/step - loss: 0.2142 - accuracy: 0.9792 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 9/50
# 6/6 [==============================] - 1s 176ms/step - loss: 2.9620e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 10/50
# 6/6 [==============================] - 1s 183ms/step - loss: 1.1783e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 11/50
# 6/6 [==============================] - 1s 178ms/step - loss: 1.5593e-04 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 12/50
# 6/6 [==============================] - 1s 180ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.0344e-05 - val_accuracy: 1.0000
# Epoch 13/50
# 6/6 [==============================] - 1s 182ms/step - loss: 5.5697e-04 - accuracy: 1.0000 - val_loss: 2.2848e-07 - val_accuracy: 1.0000
# Epoch 14/50
# 6/6 [==============================] - 1s 185ms/step - loss: 5.0063e-06 - accuracy: 1.0000 - val_loss: 2.1855e-07 - val_accuracy: 1.0000
# Epoch 15/50
# 6/6 [==============================] - 1s 189ms/step - loss: 1.5348e-06 - accuracy: 1.0000 - val_loss: 2.0862e-07 - val_accuracy: 1.0000
# Epoch 16/50
# 6/6 [==============================] - 1s 180ms/step - loss: 4.4500e-05 - accuracy: 1.0000 - val_loss: 7.9473e-08 - val_accuracy: 1.0000
# Epoch 17/50
# 6/6 [==============================] - 1s 185ms/step - loss: 0.0805 - accuracy: 0.9792 - val_loss: 1.7851 - val_accuracy: 0.9167
# Epoch 18/50
# 6/6 [==============================] - 1s 184ms/step - loss: 7.8409e-04 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 19/50
# 6/6 [==============================] - 1s 177ms/step - loss: 3.9174e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 20/50
# 6/6 [==============================] - 1s 176ms/step - loss: 1.1031 - accuracy: 0.8750 - val_loss: 1.2756 - val_accuracy: 0.9167
# Epoch 21/50
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0280 - accuracy: 0.9792 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 22/50
# 6/6 [==============================] - 1s 174ms/step - loss: 2.3038e-05 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 23/50
# 6/6 [==============================] - 1s 173ms/step - loss: 8.7660e-05 - accuracy: 1.0000 - val_loss: 3.8425e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 6/6 [==============================] - 1s 179ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9167
# Epoch 25/50
# 6/6 [==============================] - 1s 181ms/step - loss: 0.0722 - accuracy: 0.9792 - val_loss: 5.0120e-04 - val_accuracy: 1.0000
# Epoch 26/50
# 6/6 [==============================] - 1s 179ms/step - loss: 2.6317e-04 - accuracy: 1.0000 - val_loss: 1.7285e-06 - val_accuracy: 1.0000
# Epoch 27/50
# 6/6 [==============================] - 1s 182ms/step - loss: 9.5862e-07 - accuracy: 1.0000 - val_loss: 1.6292e-06 - val_accuracy: 1.0000
# Epoch 28/50
# 6/6 [==============================] - 1s 178ms/step - loss: 6.6309e-07 - accuracy: 1.0000 - val_loss: 1.6193e-06 - val_accuracy: 1.0000
# Epoch 29/50
# 6/6 [==============================] - 1s 179ms/step - loss: 0.0903 - accuracy: 0.9792 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 30/50
# 6/6 [==============================] - 1s 175ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.7311e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 6/6 [==============================] - 1s 181ms/step - loss: 1.4379e-06 - accuracy: 1.0000 - val_loss: 3.5991e-04 - val_accuracy: 1.0000
# Epoch 32/50
# 6/6 [==============================] - 1s 186ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 3.5957e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 6/6 [==============================] - 1s 185ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 3.5941e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 6/6 [==============================] - 1s 181ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 35/50
# 6/6 [==============================] - 1s 174ms/step - loss: 6.9290e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 36/50
# 6/6 [==============================] - 1s 191ms/step - loss: 9.4374e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 37/50
# 6/6 [==============================] - 1s 182ms/step - loss: 2.0479e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 38/50
# 6/6 [==============================] - 1s 191ms/step - loss: 8.6733e-04 - accuracy: 1.0000 - val_loss: 3.8743e-07 - val_accuracy: 1.0000
# Epoch 39/50
# 6/6 [==============================] - 1s 195ms/step - loss: 1.8174e-05 - accuracy: 1.0000 - val_loss: 2.7914e-06 - val_accuracy: 1.0000
# Epoch 40/50
# 6/6 [==============================] - 1s 189ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 4.9671e-08 - val_accuracy: 1.0000
# Epoch 41/50
# 6/6 [==============================] - 1s 179ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.9671e-08 - val_accuracy: 1.0000
# Epoch 42/50
# 6/6 [==============================] - 1s 179ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 4.9671e-08 - val_accuracy: 1.0000
# Epoch 43/50
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.8057 - val_accuracy: 0.8333
# Epoch 44/50
# 6/6 [==============================] - 1s 172ms/step - loss: 0.0422 - accuracy: 0.9583 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 45/50
# 6/6 [==============================] - 1s 171ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 46/50
# 6/6 [==============================] - 1s 172ms/step - loss: 9.6857e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 47/50
# 6/6 [==============================] - 1s 175ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 48/50
# 6/6 [==============================] - 1s 171ms/step - loss: 4.1475e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 49/50
# 6/6 [==============================] - 1s 175ms/step - loss: 4.4703e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 50/50
# 6/6 [==============================] - 1s 172ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Loss en test: 0.0, Accuracy en test: 1.0

# %% [markdown]
# ## Visualizamos la funcion de perdida y la precision

# %%
import matplotlib.pyplot as plt

# Crear figura
fig = plt.figure(figsize=(10, 8))

# Gráfico de la función de pérdida
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(history.history['loss'], label='Pérdida de entrenamiento')
ax1.plot(history.history['val_loss'], label='Pérdida de validación', linestyle='--')
ax1.set_title('Función de pérdida')
ax1.set_ylabel('Pérdida')
ax1.legend(loc='upper right')

# Gráfico de precisión
ax2 = fig.add_subplot(2, 1, 2, sharex=ax1)
ax2.plot(history.history['accuracy'], label='Precisión de entrenamiento')
ax2.plot(history.history['val_accuracy'], label='Precisión de validación', linestyle='--')
ax2.set_title('Precisión')
ax2.set_ylabel('Precisión')
ax2.set_xlabel('Épocas')
ax2.legend(loc='lower right')

# Ocultar etiquetas de los ejes x del primer gráfico
plt.setp(ax1.get_xticklabels(), visible=False)

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Matriz de confusion

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predicciones del modelo
y_pred = np.argmax(model.predict(x_test), axis=1)
y_true = np.argmax(y_test, axis=1)

# Matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred)

# Visualización de la matriz de confusión
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Métricas
print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))
# Out:
# 1/1 [==============================] - 2s 2s/step
#               precision    recall  f1-score   support
#
#        autos       1.00      1.00      1.00         4
#      aviones       1.00      1.00      1.00         2
#     camiones       1.00      1.00      1.00         6
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12

# %% [markdown]
# ## Guardamos el modelo para ocuparlo posteriormente

# %%
# Guardar el modelo en la ruta especificada
save_path = r"C:\Users\Diego\Tarea UDD\Clase 3\modelo_fusionado.h5"
model.save(save_path)
print(f"Modelo guardado en: {save_path}")
# Out:
# C:\Users\Diego\anaconda3\envs\gpu\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Modelo guardado en: C:\Users\Diego\Tarea UDD\Clase 3\modelo_fusionado.h5

# %% [markdown]
# ## Cargamos el modelo para que este listo para ser usado en nuestra carpeta de test

# %%
from tensorflow.keras.models import load_model

# Ruta del modelo guardado
load_path = r"C:\Users\Diego\Tarea UDD\Clase 3\modelo_fusionado.h5"
# Cargar el modelo
loaded_model = load_model(load_path)
print(f"Modelo cargado desde: {load_path}")
# Out:
# Modelo cargado desde: C:\Users\Diego\Tarea UDD\Clase 3\modelo_fusionado.h5

# %% [markdown]
# ## Cargamos nuestra carpeta de test y ajustamos las dimensiones de las imagenes

# %%
import os
import numpy as np
from PIL import Image

# Ruta del dataset "train"
train_dataset_path = r"C:\Users\Diego\Tarea UDD\Clase 3\test"

# Dimensiones de las imágenes (deben coincidir con el modelo)
img_height, img_width = 128, 128

# Procesar las imágenes dentro de subcarpetas
x_train_data = []
image_names = []
labels = []  # Opcional: guardar el nombre de la clase para referencia

for class_name in os.listdir(train_dataset_path):
    class_path = os.path.join(train_dataset_path, class_name)
    if os.path.isdir(class_path):  # Solo procesar directorios
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            try:
                # Verificar que sea un archivo de imagen
                if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                    img = Image.open(img_path).convert("RGB")
                    img = img.resize((img_width, img_height))
                    x_train_data.append(np.array(img))
                    image_names.append(img_name)
                    labels.append(class_name)  # Opcional: asociar con la clase
            except Exception as e:
                print(f"Error al procesar la imagen {img_name}: {e}")

# Convertir a NumPy array y normalizar
x_train_data = np.array(x_train_data, dtype="float32") / 255.0

# %% [markdown]
# ## Ocupamos el modelo para hacer predicciones

# %%
# Cargar el modelo guardado
model_path = r"C:\Users\Diego\Tarea UDD\Clase 3\modelo_fusionado.h5"
model = load_model(model_path)

# Realizar predicciones
predictions = model.predict(x_train_data)

# Convertir predicciones a etiquetas
predicted_labels = np.argmax(predictions, axis=1)

# Crear un grid para visualizar las imágenes con predicciones
num_images = len(x_train_data)
num_cols = 3
num_rows = (num_images + num_cols - 1) // num_cols  # Calcular filas necesarias

plt.figure(figsize=(15, 5 * num_rows))

for i, (img, label) in enumerate(zip(x_train_data, predicted_labels)):
    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(img)
    plt.title(f"Clase predicha: {label_encoder.inverse_transform([label])[0]}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
